# %%
import os
import random
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import re
import scipy.io
import pandas as pd

# %%
# TensorFlow settings and training parameters
AUTOTUNE = tf.data.experimental.AUTOTUNE
EPOCHS = 500
BATCH_SIZE = 16
PATIENCE = 10
LEARNING_RATE = 1e-3
IMAGE_SIZE = 299
INITIAL_EPOCH = 0

# %%
def load_image(is_labelled: bool, is_training=True):
  def _get_image(path: str) -> tf.Tensor:
    image = tf.image.decode_jpeg(tf.io.read_file(path), channels=3)
    image = tf.cast(image, dtype=tf.int32)
    image = tf.image.resize_with_pad(image, IMAGE_SIZE, IMAGE_SIZE)
    if is_training:
        image = tf.image.random_flip_left_right(image)
        image = tf.image.random_brightness(image, 0.1)
        image = tf.image.random_contrast(image, 0.1, 0.2)
        image = tf.image.random_saturation(image, 0.9, 1.1)
        image = tf.image.random_hue(image, 0.1)
    return tf.keras.applications.inception_resnet_v2.preprocess_input(image)

  def _get_image_label(img: tf.Tensor, label: int) -> tuple:
    return _get_image(img), label

  return _get_image_label if is_labelled else _get_image

# %%
def prepare_dataset(dataset, is_training=True, is_labeled=True):
  image_read_fn = load_image(is_labeled, is_training)
  dataset = dataset.map(image_read_fn, num_parallel_calls=AUTOTUNE)
  return dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)

# %%
def create_model() -> tf.keras.Model:
  feature_model = tf.keras.applications.InceptionResNetV2(
  include_top=False, pooling='avg')
  feature_model.trainable = False

  model = tf.keras.Sequential([
      tf.keras.Input((IMAGE_SIZE, IMAGE_SIZE, 3)),
      feature_model,
      tf.keras.layers.Dense(512, activation='selu'),
      tf.keras.layers.Dense(1)
  ])

  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                loss=tf.keras.losses.MeanSquaredError(),
                metrics=[tf.keras.metrics.MeanAbsoluteError()])

  return model

# %%
def set_seed(seed=42):
    np.random.seed(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

# %%
def reconstruct_path(image_id: int) -> str:
    image_id = str(image_id).rjust(6, '0')
    return f'drive/MyDrive/TIES4911/mini-project/frames/seq_{image_id}.jpg'

# %%
set_seed()

# %%
META_FILE = 'drive/MyDrive/TIES4911/mini-project/labels.csv'

# %%
data = pd.read_csv(META_FILE)
data['path'] = data['id'].apply(reconstruct_path)
data.head()
# Out:
#    id  count                                               path
# 0   1     35  drive/MyDrive/TIES4911/mini-project/frames/seq...
# 1   2     41  drive/MyDrive/TIES4911/mini-project/frames/seq...
# 2   3     41  drive/MyDrive/TIES4911/mini-project/frames/seq...
# 3   4     44  drive/MyDrive/TIES4911/mini-project/frames/seq...
# 4   5     41  drive/MyDrive/TIES4911/mini-project/frames/seq...

# %%
mat = scipy.io.loadmat('drive/MyDrive/TIES4911/mini-project/mall_gt.mat')
count = [[element for element in upperElement] for upperElement in mat['count']]
count = list(map(lambda x: x[0], count))
count

# %%
# Create train and validation data sets.
data_train = data.head(1700)
data_valid = data.tail(300)

ds_train = tf.data.Dataset.from_tensor_slices((data_train['path'], count[:1700]))
ds_valid = tf.data.Dataset.from_tensor_slices((data_valid['path'], count[1700:]))

ds_train = prepare_dataset(ds_train)
ds_valid = prepare_dataset(ds_valid, is_training=False)

# %%
checkpoint_path = "drive/MyDrive/TIES4911/mini-project/training-2/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# %%
latest = tf.train.latest_checkpoint(checkpoint_dir)
latest

# %%
model = create_model()

if latest:
  model.load_weights(latest)
  INITIAL_EPOCH = int(re.findall(r".cp-(\d{4})\.ckpt", latest)[0])
else:
  INITIAL_EPOCH = 0

model.save_weights(checkpoint_path.format(epoch=0))

# %%
INITIAL_EPOCH
# Out:
# 0

# %%
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    save_weights_only=True,
    save_freq=5*BATCH_SIZE)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=PATIENCE,
    restore_best_weights=True)

lr_reduction = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', patience=1, cooldown=1, verbose=1,
    factor=0.75, min_lr=1e-8)

history = model.fit(ds_train, validation_data=ds_valid, batch_size=BATCH_SIZE,
                    initial_epoch=INITIAL_EPOCH, epochs=EPOCHS, callbacks=[cp_callback, early_stop, lr_reduction],
                    use_multiprocessing=True, workers=os.cpu_count())
# Out:
# Epoch 1/500
#  79/107 [=====================>........] - ETA: 4:20 - loss: 112.8664 - mean_absolute_error: 8.3934
# Epoch 1: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0001.ckpt
# 107/107 [==============================] - 1209s 11s/step - loss: 95.0271 - mean_absolute_error: 7.6733 - val_loss: 28.6393 - val_mean_absolute_error: 4.5429 - lr: 0.0010
# Epoch 2/500
#  52/107 [=============>................] - ETA: 8:23 - loss: 58.3247 - mean_absolute_error: 6.1930
# Epoch 2: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0002.ckpt
# 107/107 [==============================] - 1149s 11s/step - loss: 44.9229 - mean_absolute_error: 5.4275 - val_loss: 27.4227 - val_mean_absolute_error: 4.4786 - lr: 0.0010
# Epoch 3/500
#  25/107 [======>.......................] - ETA: 12:24 - loss: 40.8092 - mean_absolute_error: 4.8715
# Epoch 3: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0003.ckpt
# 105/107 [============================>.] - ETA: 18s - loss: 39.3075 - mean_absolute_error: 5.0148
# Epoch 3: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0003.ckpt
# 107/107 [==============================] - ETA: 0s - loss: 39.8195 - mean_absolute_error: 5.0597
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
# 107/107 [==============================] - 1173s 11s/step - loss: 39.8195 - mean_absolute_error: 5.0597 - val_loss: 30.2454 - val_mean_absolute_error: 4.7406 - lr: 0.0010
# Epoch 4/500
#  78/107 [====================>.........] - ETA: 4:24 - loss: 40.1777 - mean_absolute_error: 4.8341
# Epoch 4: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0004.ckpt
# 107/107 [==============================] - ETA: 0s - loss: 38.0098 - mean_absolute_error: 4.7866
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005625000048894435.
# 107/107 [==============================] - 1174s 11s/step - loss: 38.0098 - mean_absolute_error: 4.7866 - val_loss: 35.7875 - val_mean_absolute_error: 5.2010 - lr: 7.5000e-04
# Epoch 5/500
#  51/107 [=============>................] - ETA: 8:31 - loss: 50.3989 - mean_absolute_error: 5.4103
# Epoch 5: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0005.ckpt
# 107/107 [==============================] - ETA: 0s - loss: 37.4391 - mean_absolute_error: 4.7184
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0004218749818392098.
# 107/107 [==============================] - 1184s 11s/step - loss: 37.4391 - mean_absolute_error: 4.7184 - val_loss: 28.4214 - val_mean_absolute_error: 4.5985 - lr: 5.6250e-04
# Epoch 6/500
#  24/107 [=====>........................] - ETA: 12:42 - loss: 43.8827 - mean_absolute_error: 5.3573
# Epoch 6: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0006.ckpt
# 104/107 [============================>.] - ETA: 27s - loss: 35.6387 - mean_absolute_error: 4.6262
# Epoch 6: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0006.ckpt
# 107/107 [==============================] - 1191s 11s/step - loss: 35.5871 - mean_absolute_error: 4.6381 - val_loss: 21.1905 - val_mean_absolute_error: 3.9228 - lr: 4.2187e-04
# Epoch 7/500
#  77/107 [====================>.........] - ETA: 4:33 - loss: 35.3466 - mean_absolute_error: 4.5819
# Epoch 7: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0007.ckpt
# 107/107 [==============================] - 1182s 11s/step - loss: 32.9801 - mean_absolute_error: 4.4691 - val_loss: 21.1198 - val_mean_absolute_error: 3.9166 - lr: 4.2187e-04
# Epoch 8/500
#  50/107 [=============>................] - ETA: 8:44 - loss: 41.9094 - mean_absolute_error: 5.0318
# Epoch 8: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0008.ckpt
# 107/107 [==============================] - ETA: 0s - loss: 31.6022 - mean_absolute_error: 4.3674
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
# 107/107 [==============================] - 1175s 11s/step - loss: 31.6022 - mean_absolute_error: 4.3674 - val_loss: 21.2480 - val_mean_absolute_error: 3.9294 - lr: 4.2187e-04
# Epoch 9/500
#  23/107 [=====>........................] - ETA: 12:38 - loss: 32.8630 - mean_absolute_error: 4.7276
# Epoch 9: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0009.ckpt
# 103/107 [===========================>..] - ETA: 36s - loss: 30.7575 - mean_absolute_error: 4.3394
# Epoch 9: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0009.ckpt
# 107/107 [==============================] - 1183s 11s/step - loss: 30.4616 - mean_absolute_error: 4.3271 - val_loss: 17.5207 - val_mean_absolute_error: 3.4594 - lr: 3.1641e-04
# Epoch 10/500
#  76/107 [====================>.........] - ETA: 4:40 - loss: 30.4244 - mean_absolute_error: 4.3158
# Epoch 10: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0010.ckpt
# 107/107 [==============================] - ETA: 0s - loss: 28.7257 - mean_absolute_error: 4.2135
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00023730468819849193.
# 107/107 [==============================] - 1137s 11s/step - loss: 28.7257 - mean_absolute_error: 4.2135 - val_loss: 18.0064 - val_mean_absolute_error: 3.5277 - lr: 3.1641e-04
# Epoch 11/500
#  49/107 [============>.................] - ETA: 8:46 - loss: 36.0698 - mean_absolute_error: 4.8348
# Epoch 11: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0011.ckpt
# 107/107 [==============================] - 1173s 11s/step - loss: 28.0822 - mean_absolute_error: 4.2089 - val_loss: 16.0078 - val_mean_absolute_error: 3.2078 - lr: 2.3730e-04
# Epoch 12/500
#  22/107 [=====>........................] - ETA: 12:59 - loss: 25.5338 - mean_absolute_error: 4.2311
# Epoch 12: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0012.ckpt
# 102/107 [===========================>..] - ETA: 45s - loss: 26.7851 - mean_absolute_error: 4.1078
# Epoch 12: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0012.ckpt
# 107/107 [==============================] - ETA: 0s - loss: 26.5675 - mean_absolute_error: 4.1017
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00017797851614886895.
# 107/107 [==============================] - 1181s 11s/step - loss: 26.5675 - mean_absolute_error: 4.1017 - val_loss: 16.2371 - val_mean_absolute_error: 3.2527 - lr: 2.3730e-04
# Epoch 13/500
#  75/107 [====================>.........] - ETA: 4:51 - loss: 27.0100 - mean_absolute_error: 4.1588
# Epoch 13: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0013.ckpt
# 107/107 [==============================] - 1182s 11s/step - loss: 26.1866 - mean_absolute_error: 4.1015 - val_loss: 15.5925 - val_mean_absolute_error: 3.1087 - lr: 1.7798e-04
# Epoch 14/500
#  48/107 [============>.................] - ETA: 9:00 - loss: 30.5066 - mean_absolute_error: 4.4926
# Epoch 14: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0014.ckpt
# 107/107 [==============================] - 1184s 11s/step - loss: 24.9115 - mean_absolute_error: 3.9985 - val_loss: 15.5279 - val_mean_absolute_error: 3.1187 - lr: 1.7798e-04
# Epoch 15/500
#  21/107 [====>.........................] - ETA: 12:56 - loss: 23.5257 - mean_absolute_error: 4.0593
# Epoch 15: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0015.ckpt
# 101/107 [===========================>..] - ETA: 55s - loss: 24.7903 - mean_absolute_error: 3.9779
# Epoch 15: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0015.ckpt
# 107/107 [==============================] - ETA: 0s - loss: 24.5326 - mean_absolute_error: 3.9671
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0001334838816546835.
# 107/107 [==============================] - 1191s 11s/step - loss: 24.5326 - mean_absolute_error: 3.9671 - val_loss: 15.5516 - val_mean_absolute_error: 3.1353 - lr: 1.7798e-04
# Epoch 16/500
#  74/107 [===================>..........] - ETA: 5:00 - loss: 24.7005 - mean_absolute_error: 3.9933
# Epoch 16: saving model to drive/MyDrive/TIES4911/mini-project/training-2/cp-0016.ckpt
# 107/107 [==============================] - ETA: 0s - loss: 24.2374 - mean_absolute_error: 3.9638

# %%
mse, mae = model.evaluate(ds_valid)
print(f'Validation MSE = {mse}\n'
      f'Validation MAE = {mae}')

# %%
model.save('drive/MyDrive/TIES4911/mini-project/model.h5')
